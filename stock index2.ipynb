# %%
import investpy
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta
import altair as alt
import pandas as pd

# %%
today = datetime.today().strftime('%d/%m/%Y')

# %%
uk_index =investpy.indices.get_indices(country="united kingdom")
f_index =investpy.indices.get_indices(country="france")

# %%
uk_index[uk_index['full_name'].str.contains('FTSE 100')]
# Out:
#             country                                             name  \
# 0    united kingdom                        FTSE 100 Minimum Variance
# 33   united kingdom  FTSE 100 Daily Ultra Short Strategy RT Gross TR
# 34   united kingdom             FTSE 100 Daily Super Leveraged RT TR
# 56   united kingdom                FTSE 100 Equally Weighted Net Tax
# 57   united kingdom                             FTSE 100 Daily Short
# 58   united kingdom                                     FTSE 100 USD
# 80   united kingdom                            FTSE 100 Total Return
# 136  united kingdom                                         FTSE 100
#
#                                            full_name    symbol currency  \
# 0                          FTSE 100 Minimum Variance   FTUKXMV      GBP
# 33   FTSE 100 Daily Ultra Short Strategy RT Gross TR  FTUKXI3X      GBP
# 34              FTSE 100 Daily Super Leveraged RT TR  FTUKXL3X      GBP
# 56                 FTSE 100 Equally Weighted Net Tax   FTUKXEQ      GBP
# 57                              FTSE 100 Daily Short    FTUKXS      GBP
# 58                                      FTSE 100 USD  FTUKXUSD      USD
# 80                             FTSE 100 Total Return    TRIUKX      GBP
# 136                                         FTSE 100      FTSE      GBP
#
#              class          market
# 0    other_indices  global_indices
# 33   other_indices  global_indices
# 34   other_indices  global_indices
# 56   other_indices  global_indices
# 57   other_indices  global_indices
# 58   other_indices  global_indices
# 80   other_indices   world_indices
# 136  major_indices   world_indices

# %%
ftse = investpy.get_index_historical_data(index='FTSE 100',country='united kingdom',
                                        from_date='01/01/2010',to_date=today)
ftse
# Out:
#                Open     High      Low    Close     Volume Currency
# Date
# 2010-01-04  5412.90  5500.30  5410.80  5500.30          0      GBP
# 2010-01-05  5500.30  5536.40  5480.70  5522.50          0      GBP
# 2010-01-06  5522.50  5536.50  5497.60  5530.00          0      GBP
# 2010-01-07  5530.00  5551.70  5499.80  5526.70          0      GBP
# 2010-01-08  5526.70  5549.30  5494.80  5534.20          0      GBP
# ...             ...      ...      ...      ...        ...      ...
# 2021-09-27  7051.48  7122.09  7043.21  7063.40  900054016      GBP
# 2021-09-28  7063.40  7071.36  7015.58  7028.10  818880000      GBP
# 2021-09-29  7028.10  7117.52  7026.85  7108.16  810524992      GBP
# 2021-09-30  7108.16  7159.61  7072.57  7086.42  867449984      GBP
# 2021-10-01  7086.42  7086.42  6989.64  7027.07  815417024      GBP
#
# [2969 rows x 6 columns]

# %%
ftse.index = ftse.index.strftime('%Y/%m/%d')
ftse = ftse.T
ftse = ftse.T.reset_index()
ftse
# Out:
#             Date     Open     High      Low    Close     Volume Currency
# 0     2010/01/04   5412.9   5500.3   5410.8   5500.3          0      GBP
# 1     2010/01/05   5500.3   5536.4   5480.7   5522.5          0      GBP
# 2     2010/01/06   5522.5   5536.5   5497.6   5530.0          0      GBP
# 3     2010/01/07   5530.0   5551.7   5499.8   5526.7          0      GBP
# 4     2010/01/08   5526.7   5549.3   5494.8   5534.2          0      GBP
# ...          ...      ...      ...      ...      ...        ...      ...
# 2964  2021/09/27  7051.48  7122.09  7043.21   7063.4  900054016      GBP
# 2965  2021/09/28   7063.4  7071.36  7015.58   7028.1  818880000      GBP
# 2966  2021/09/29   7028.1  7117.52  7026.85  7108.16  810524992      GBP
# 2967  2021/09/30  7108.16  7159.61  7072.57  7086.42  867449984      GBP
# 2968  2021/10/01  7086.42  7086.42  6989.64  7027.07  815417024      GBP
#
# [2969 rows x 7 columns]

# %%
chart =(
    alt.Chart(ftse)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)

# %%
f_index[f_index['full_name'].str.contains('CAC 40')]
# Out:
#    country                         name                    full_name   symbol  \
# 6   france                       CAC 40                       CAC 40     FCHI
# 25  france       CAC 40 Equal Weight GR       CAC 40 Equal Weight GR    CACEG
# 45  france    CAC 40 x3 Levereged Short    CAC 40 x3 Levereged Short    CAC3S
# 46  france          CAC 40 x3 Levereged          CAC 40 x3 Levereged    CAC3L
# 51  france       CAC 40 Equal Weight NR       CAC 40 Equal Weight NR    CACEN
# 56  france              CAC 40 Gross TR    CAC 40 Gross Total Return    PX1GR
# 57  france            CAC 40 Settlement            CAC 40 Settlement  FCHISET
# 58  france       CAC 40 Leverage x10 NR       CAC 40 Leverage x10 NR    CA10L
# 84  france               CAC 40 Long x3               CAC 40 Long x3     CA3L
# 85  france                CAC 40 Net TR      CAC 40 Net Total Return    PX1NR
# 86  france  CAC 40 Performance Weighted  CAC 40 Performance Weighted     CAPW
# 88  france              CAC 40 Short GR              CAC 40 Short GR    CACSH
# 89  france           CAC 40 Short x2 GR           CAC 40 Short x2 GR    CAC2S
# 90  france                   CAC 40 VIX                   CAC 40 VIX     VCAC
# 91  france             CAC 40 X10 SHORT             CAC 40 X10 SHORT    CA10S
# 93  france              CAC 40 x5 Short              CAC 40 x5 Short    CAC5S
#
#    currency          class          market
# 6       EUR  major_indices   world_indices
# 25      EUR  other_indices   world_indices
# 45      EUR  other_indices  global_indices
# 46      EUR  other_indices  global_indices
# 51      EUR  other_indices   world_indices
# 56      EUR  other_indices   world_indices
# 57      EUR  other_indices   world_indices
# 58      EUR  other_indices   world_indices
# 84      EUR  other_indices   world_indices
# 85      EUR  other_indices   world_indices
# 86      EUR  other_indices   world_indices
# 88      EUR  other_indices   world_indices
# 89      EUR  other_indices   world_indices
# 90      EUR  other_indices   world_indices
# 91      EUR  other_indices   world_indices
# 93      EUR  other_indices   world_indices

# %%
cac40 = investpy.get_index_historical_data(index='CAC 40',country='france',
                                        from_date='01/01/2010',to_date=today)

# %%
cac40.index = cac40.index.strftime('/%Y/%m/%d')
cac40 = cac40.T
cac40 = cac40.T.reset_index()

# %%
chart =(
    alt.Chart(cac40)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)
