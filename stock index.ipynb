# %%
import investpy
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta
import altair as alt
import pandas as pd

# %%
today = datetime.today().strftime('%d/%m/%Y')

# %%
df = investpy.get_index_historical_data(index='S&P 500',country='united states',
                                        from_date='01/01/2010',to_date=today)

# %%
df.index = df.index.strftime('%Y/%m/%d')

# %%
df = df.T
df
# Out:
# Date     2010/01/04 2010/01/05 2010/01/06 2010/01/07 2010/01/08 2010/01/11  \
# Open        1116.56    1132.66    1135.71    1136.27    1140.52    1145.96
# High        1133.87    1136.63    1139.19    1142.46    1145.39    1149.74
# Low         1116.56    1129.66    1133.95    1131.32    1136.22    1142.02
# Close       1132.99    1136.52    1137.14    1141.69    1144.98    1146.98
# Volume            0          0          0          0          0          0
# Currency        USD        USD        USD        USD        USD        USD
#
# Date     2010/01/12 2010/01/13 2010/01/14 2010/01/15  ... 2021/09/20  \
# Open        1143.81    1137.31    1145.68    1147.72  ...    4402.95
# High        1143.81     1148.4    1150.41    1147.77  ...    4402.95
# Low         1131.77    1133.18     1143.8    1131.39  ...    4305.91
# Close       1136.22    1145.68    1148.46    1136.03  ...    4357.73
# Volume            0          0          0          0  ...          0
# Currency        USD        USD        USD        USD  ...        USD
#
# Date     2021/09/21 2021/09/22 2021/09/23 2021/09/24 2021/09/27 2021/09/28  \
# Open        4374.45    4367.43    4406.75    4438.04    4442.12    4419.54
# High        4394.87    4416.75     4465.4    4463.12     4457.3    4419.54
# Low         4347.96    4367.43    4406.75    4430.27    4436.19    4346.33
# Close       4354.18    4395.64    4448.98    4455.48    4443.11    4352.63
# Volume            0          0          0          0          0          0
# Currency        USD        USD        USD        USD        USD        USD
#
# Date     2021/09/29 2021/09/30 2021/10/01
# Open        4362.41    4370.67    4317.16
# High        4385.57    4382.55    4375.19
# Low         4355.08    4306.24    4288.52
# Close       4359.46    4307.54    4357.05
# Volume            0          0          0
# Currency        USD        USD        USD
#
# [6 rows x 2958 columns]

# %%
df= df.T.reset_index()

# %%
chart =(
    alt.Chart(df)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)

# %%
chart
# Out:
# alt.Chart(...)

# %%
df
# Out:
#             Date     Open     High      Low    Close Volume Currency
# 0     2010/01/04  1116.56  1133.87  1116.56  1132.99      0      USD
# 1     2010/01/05  1132.66  1136.63  1129.66  1136.52      0      USD
# 2     2010/01/06  1135.71  1139.19  1133.95  1137.14      0      USD
# 3     2010/01/07  1136.27  1142.46  1131.32  1141.69      0      USD
# 4     2010/01/08  1140.52  1145.39  1136.22  1144.98      0      USD
# ...          ...      ...      ...      ...      ...    ...      ...
# 2953  2021/09/27  4442.12   4457.3  4436.19  4443.11      0      USD
# 2954  2021/09/28  4419.54  4419.54  4346.33  4352.63      0      USD
# 2955  2021/09/29  4362.41  4385.57  4355.08  4359.46      0      USD
# 2956  2021/09/30  4370.67  4382.55  4306.24  4307.54      0      USD
# 2957  2021/10/01  4317.16  4375.19  4288.52  4357.05      0      USD
#
# [2958 rows x 7 columns]

# %%
stock_index =investpy.indices.get_indices(country="united states")
stock_index[stock_index['class']=='primary_sectors']
# Out:
#             country                           name  \
# 375   united states                  NQ Industrial
# 376   united states                   NQ Insurance
# 377   united states                    NQ Internet
# 378   united states               NQ Other Finance
# 379   united states          NQ Telecommunications
# ...             ...                            ...
# 1336  united states       DJ U.S. Select Insurance
# 1342  united states      NQ US Technology Dividend
# 1344  united states           DJ US Select Telecom
# 1361  united states         NQ US Benchmark Mining
# 1377  united states  DJ Global ex-U.S. Select REIT
#
#                                    full_name     symbol currency  \
# 375                        NASDAQ Industrial       IXID      USD
# 376                         NASDAQ Insurance       IXIS      USD
# 377                          NASDAQ Internet       QNET      USD
# 378                     NASDAQ Other Finance       IXFN      USD
# 379                NASDAQ Telecommunications       IXUT      USD
# ...                                      ...        ...      ...
# 1336           Dow Jones US Select Insurance     DJSINS      USD
# 1342           NASDAQ US Technology Dividend  NQ96DIVUS      USD
# 1344  Dow Jones US Select Telecommunications     DJSTEL      USD
# 1361              NASDAQ US Benchmark Mining  NQUSB1770      USD
# 1377      Dow Jones Global ex-US Select REIT      DWXRT      USD
#
#                 class          market
# 375   primary_sectors   world_indices
# 376   primary_sectors   world_indices
# 377   primary_sectors   world_indices
# 378   primary_sectors   world_indices
# 379   primary_sectors   world_indices
# ...               ...             ...
# 1336  primary_sectors  global_indices
# 1342  primary_sectors  global_indices
# 1344  primary_sectors  global_indices
# 1361  primary_sectors  global_indices
# 1377  primary_sectors  global_indices
#
# [64 rows x 7 columns]

# %%
vix = investpy.get_index_historical_data(index='S&P 500 VIX',country='united states',
                                        from_date='01/01/2010',to_date=today)
vix
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2010-01-04  21.68  21.68  20.03  20.04       0      USD
# 2010-01-05  20.05  20.13  19.34  19.35       0      USD
# 2010-01-06  19.59  19.68  18.77  19.16       0      USD
# 2010-01-07  19.68  19.71  18.70  19.06       0      USD
# 2010-01-08  19.27  19.27  18.11  18.13       0      USD
# ...           ...    ...    ...    ...     ...      ...
# 2021-09-27  17.78  19.32  17.74  18.76       0      USD
# 2021-09-28  19.74  24.82  19.71  23.25       0      USD
# 2021-09-29  22.07  23.79  21.45  22.56       0      USD
# 2021-09-30  21.48  24.71  20.60  23.14       0      USD
# 2021-10-01  23.14  24.89  20.64  21.15       0      USD
#
# [2963 rows x 6 columns]

# %%
vix = vix.T
vix = vix.T.reset_index()

# %%
chart =(
    alt.Chart(vix)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)

# %%
dow =  investpy.get_index_historical_data(index='Dow 30',country='united states',
                                        from_date='01/01/2010',to_date=today)
dow
# Out:
#                 Open      High       Low     Close     Volume Currency
# Date
# 2010-01-04  10430.69  10604.97  10430.69  10583.96  179781696      USD
# 2010-01-05  10584.56  10584.56  10522.52  10572.02  188542224      USD
# 2010-01-06  10564.72  10594.99  10546.55  10573.68  186042928      USD
# 2010-01-07  10571.11  10612.37  10505.21  10606.86  217391184      USD
# 2010-01-08  10606.40  10619.40  10554.33  10618.19  172712176      USD
# ...              ...       ...       ...       ...        ...      ...
# 2021-09-27  34809.77  35060.25  34809.77  34870.16  276789632      USD
# 2021-09-28  34747.70  34795.26  34254.65  34299.53  369064992      USD
# 2021-09-29  34360.08  34579.87  34309.22  34390.92  280485408      USD
# 2021-09-30  34467.98  34557.37  33833.32  33843.33  337439968      USD
# 2021-10-01  33930.70  34490.19  33785.54  34327.45  412089856      USD
#
# [2958 rows x 6 columns]

# %%
dow=dow.T
dow = dow.T.reset_index()
dow
# Out:
#            Date      Open      High       Low     Close     Volume Currency
# 0    2010-01-04  10430.69  10604.97  10430.69  10583.96  179781696      USD
# 1    2010-01-05  10584.56  10584.56  10522.52  10572.02  188542224      USD
# 2    2010-01-06  10564.72  10594.99  10546.55  10573.68  186042928      USD
# 3    2010-01-07  10571.11  10612.37  10505.21  10606.86  217391184      USD
# 4    2010-01-08   10606.4   10619.4  10554.33  10618.19  172712176      USD
# ...         ...       ...       ...       ...       ...        ...      ...
# 2953 2021-09-27  34809.77  35060.25  34809.77  34870.16  276789632      USD
# 2954 2021-09-28   34747.7  34795.26  34254.65  34299.53  369064992      USD
# 2955 2021-09-29  34360.08  34579.87  34309.22  34390.92  280485408      USD
# 2956 2021-09-30  34467.98  34557.37  33833.32  33843.33  337439968      USD
# 2957 2021-10-01   33930.7  34490.19  33785.54  34327.45  412089856      USD
#
# [2958 rows x 7 columns]

# %%
chart =(
    alt.Chart(dow)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)

# %%
stock_index =investpy.indices.get_indices(country="united states")
stock_index[stock_index['class']=='primary_sectors'].head(35)
# Out:
#            country                             name  \
# 375  united states                    NQ Industrial
# 376  united states                     NQ Insurance
# 377  united states                      NQ Internet
# 378  united states                 NQ Other Finance
# 379  united states            NQ Telecommunications
# 380  united states                NQ Transportation
# 381  united states               NASDAQ Health Care
# 382  united states                      NYSE Energy
# 383  united states                  NYSE Healthcare
# 384  united states                         NYSE TMT
# 385  united states               PHLX Semiconductor
# 386  united states  Russell 1000 Financial Services
# 387  united states   S&P 500 Consumer Discretionary
# 388  united states         S&P 500 Consumer Staples
# 389  united states                  NYSE Financials
# 390  united states                 NQ Financial 100
# 391  united states                      NQ Computer
# 392  united states                 NQ Biotechnology
# 397  united states               DJ Basic Materials
# 398  united states                DJ Consumer Goods
# 399  united states             DJ Consumer Services
# 400  united states                    DJ Financials
# 401  united states                   DJ Health Care
# 402  united states                   DJ Industrials
# 403  united states                       DJ Oil&Gas
# 404  united states                    DJ Technology
# 405  united states                       DJ Telecom
# 406  united states                     DJ Utilities
# 407  united states                          NQ Bank
# 408  united states                   S&P 500 Energy
# 409  united states               S&P 500 Financials
# 410  united states              S&P 500 Health Care
# 411  united states              S&P 500 Industrials
# 431  united states   S&P 500 Information Technology
# 432  united states                S&P 500 Materials
#
#                             full_name   symbol currency            class  \
# 375                 NASDAQ Industrial     IXID      USD  primary_sectors
# 376                  NASDAQ Insurance     IXIS      USD  primary_sectors
# 377                   NASDAQ Internet     QNET      USD  primary_sectors
# 378              NASDAQ Other Finance     IXFN      USD  primary_sectors
# 379         NASDAQ Telecommunications     IXUT      USD  primary_sectors
# 380             NASDAQ Transportation     IXTR      USD  primary_sectors
# 381                NASDAQ Health Care      IXC      USD  primary_sectors
# 382                       NYSE Energy      NYE      USD  primary_sectors
# 383                   NYSE Healthcare      NYP      USD  primary_sectors
# 384                          NYSE TMT      NTM      USD  primary_sectors
# 385  Philadelphia Semiconductor Index      SOX      USD  primary_sectors
# 386   Russell 1000 Financial Services  R1RGSFS      USD  primary_sectors
# 387    S&P 500 Consumer Discretionary   SPLRCD      USD  primary_sectors
# 388          S&P 500 Consumer Staples   SPLRCS      USD  primary_sectors
# 389                   NYSE Financials      NYK      USD  primary_sectors
# 390              NASDAQ Financial 100      IXF      USD  primary_sectors
# 391                   NASDAQ Computer      IXK      USD  primary_sectors
# 392              NASDAQ Biotechnology      NBI      USD  primary_sectors
# 397         Dow Jones Basic Materials   DJUSBM      USD  primary_sectors
# 398          Dow Jones Consumer Goods   DJUSNC      USD  primary_sectors
# 399       Dow Jones Consumer Services   DJUSCY      USD  primary_sectors
# 400              Dow Jones Financials   DJUSFN      USD  primary_sectors
# 401             Dow Jones Health Care   DJUSHC      USD  primary_sectors
# 402             Dow Jones Industrials   DJUSIN      USD  primary_sectors
# 403               Dow Jones Oil & Gas   DJUSEN      USD  primary_sectors
# 404              Dow Jones Technology   DJUSTC      USD  primary_sectors
# 405      Dow Jones Telecommunications   DJUSTL      USD  primary_sectors
# 406               Dow Jones Utilities   DJUSUT      USD  primary_sectors
# 407                       NASDAQ Bank     IXBK      USD  primary_sectors
# 408                    S&P 500 Energy     SPNY      USD  primary_sectors
# 409                S&P 500 Financials     SPSY      USD  primary_sectors
# 410               S&P 500 Health Care    SPXHC      USD  primary_sectors
# 411               S&P 500 Industrials   SPLRCI      USD  primary_sectors
# 431    S&P 500 Information Technology   SPLRCT      USD  primary_sectors
# 432                 S&P 500 Materials   SPLRCM      USD  primary_sectors
#
#             market
# 375  world_indices
# 376  world_indices
# 377  world_indices
# 378  world_indices
# 379  world_indices
# 380  world_indices
# 381  world_indices
# 382  world_indices
# 383  world_indices
# 384  world_indices
# 385  world_indices
# 386  world_indices
# 387  world_indices
# 388  world_indices
# 389  world_indices
# 390  world_indices
# 391  world_indices
# 392  world_indices
# 397  world_indices
# 398  world_indices
# 399  world_indices
# 400  world_indices
# 401  world_indices
# 402  world_indices
# 403  world_indices
# 404  world_indices
# 405  world_indices
# 406  world_indices
# 407  world_indices
# 408  world_indices
# 409  world_indices
# 410  world_indices
# 411  world_indices
# 431  world_indices
# 432  world_indices

# %%
stock_index =investpy.indices.get_indices(country="united states")
stock_index[stock_index['class']=='primary_sectors'].tail(35)
# Out:
#             country                                             name  \
# 408   united states                                   S&P 500 Energy
# 409   united states                               S&P 500 Financials
# 410   united states                              S&P 500 Health Care
# 411   united states                              S&P 500 Industrials
# 431   united states                   S&P 500 Information Technology
# 432   united states                                S&P 500 Materials
# 433   united states                              S&P 500 Real Estate
# 434   united states                         S&P 500 Telecom Services
# 435   united states                                S&P 500 Utilities
# 1059  united states                                     MSCI US REIT
# 1060  united states                       NQ US Benchmark Technology
# 1061  united states                  NQ US Benchmark Financ Services
# 1062  united states                      NQ US Benchmark Real Estate
# 1063  united states                        NQ US Benchmark Insurance
# 1064  united states                            NQ US Benchmark Banks
# 1065  united states                       NQ US Benchmark Financials
# 1066  united states                        NQ US Benchmark Utilities
# 1067  united states               NQ US Benchmark Telecommunications
# 1068  united states                           NQ US Benchmark Retail
# 1069  united states  NQ US Benchmark Pharmaceuticals & Biotechnology
# 1070  united states                      NQ US Benchmark Health Care
# 1071  united states       NQ US Benchmark Personal & Household Goods
# 1072  united states                  NQ US Benchmark Food & Beverage
# 1073  united states              NQ US Benchmark Automobiles & Parts
# 1164  united states          NQ US Benchmark Transportation Services
# 1223  united states              NQ US Benchmark Aerospace & Defense
# 1315  united states                     NQ US Benchmark Iron & Steel
# 1318  united states                        NQ US Benchmark Chemicals
# 1320  united states                  NQ US Benchmark Basic Materials
# 1324  united states                        NQ US Benchmark Oil & Gas
# 1336  united states                         DJ U.S. Select Insurance
# 1342  united states                        NQ US Technology Dividend
# 1344  united states                             DJ US Select Telecom
# 1361  united states                           NQ US Benchmark Mining
# 1377  united states                    DJ Global ex-U.S. Select REIT
#
#                                               full_name     symbol currency  \
# 408                                      S&P 500 Energy       SPNY      USD
# 409                                  S&P 500 Financials       SPSY      USD
# 410                                 S&P 500 Health Care      SPXHC      USD
# 411                                 S&P 500 Industrials     SPLRCI      USD
# 431                      S&P 500 Information Technology     SPLRCT      USD
# 432                                   S&P 500 Materials     SPLRCM      USD
# 433                                 S&P 500 Real Estate   SPLRCREC      USD
# 434                            S&P 500 Telecom Services     SPLRCL      USD
# 435                                   S&P 500 Utilities     SPLRCU      USD
# 1059                                       MSCI US REIT        RMZ      USD
# 1060                     NASDAQ US Benchmark Technology  NQUSB9000      USD
# 1061                NASDAQ US Benchmark Financ Services  NQUSB8700      USD
# 1062                    NASDAQ US Benchmark Real Estate  NQUSB8600      USD
# 1063                      NASDAQ US Benchmark Insurance  NQUSB8500      USD
# 1064                          NASDAQ US Benchmark Banks  NQUSB8300      USD
# 1065                     NASDAQ US Benchmark Financials  NQUSB8000      USD
# 1066                      NASDAQ US Benchmark Utilities  NQUSB7000      USD
# 1067             NASDAQ US Benchmark Telecommunications  NQUSB6000      USD
# 1068                         NASDAQ US Benchmark Retail  NQUSB5300      USD
# 1069  NASDAQ US Benchmark Pharmaceuticals & Biotechn...  NQUSB4570      USD
# 1070                    NASDAQ US Benchmark Health Care  NQUSB4000      USD
# 1071     NASDAQ US Benchmark Personal & Household Goods  NQUSB3700      USD
# 1072                NASDAQ US Benchmark Food & Beverage  NQUSB3500      USD
# 1073            NASDAQ US Benchmark Automobiles & Parts  NQUSB3300      USD
# 1164        NASDAQ US Benchmark Transportation Services  NQUSB2777      USD
# 1223            NASDAQ US Benchmark Aerospace & Defense  NQUSB2710      USD
# 1315                   NASDAQ US Benchmark Iron & Steel  NQUSB1757      USD
# 1318                      NASDAQ US Benchmark Chemicals  NQUSB1300      USD
# 1320                NASDAQ US Benchmark Basic Materials  NQUSB1000      USD
# 1324                      NASDAQ US Benchmark Oil & Gas  NQUSB0001      USD
# 1336                      Dow Jones US Select Insurance     DJSINS      USD
# 1342                      NASDAQ US Technology Dividend  NQ96DIVUS      USD
# 1344             Dow Jones US Select Telecommunications     DJSTEL      USD
# 1361                         NASDAQ US Benchmark Mining  NQUSB1770      USD
# 1377                 Dow Jones Global ex-US Select REIT      DWXRT      USD
#
#                 class          market
# 408   primary_sectors   world_indices
# 409   primary_sectors   world_indices
# 410   primary_sectors   world_indices
# 411   primary_sectors   world_indices
# 431   primary_sectors   world_indices
# 432   primary_sectors   world_indices
# 433   primary_sectors   world_indices
# 434   primary_sectors   world_indices
# 435   primary_sectors   world_indices
# 1059  primary_sectors  global_indices
# 1060  primary_sectors  global_indices
# 1061  primary_sectors  global_indices
# 1062  primary_sectors  global_indices
# 1063  primary_sectors  global_indices
# 1064  primary_sectors  global_indices
# 1065  primary_sectors  global_indices
# 1066  primary_sectors  global_indices
# 1067  primary_sectors  global_indices
# 1068  primary_sectors  global_indices
# 1069  primary_sectors  global_indices
# 1070  primary_sectors  global_indices
# 1071  primary_sectors  global_indices
# 1072  primary_sectors  global_indices
# 1073  primary_sectors  global_indices
# 1164  primary_sectors  global_indices
# 1223  primary_sectors  global_indices
# 1315  primary_sectors  global_indices
# 1318  primary_sectors  global_indices
# 1320  primary_sectors  global_indices
# 1324  primary_sectors  global_indices
# 1336  primary_sectors  global_indices
# 1342  primary_sectors  global_indices
# 1344  primary_sectors  global_indices
# 1361  primary_sectors  global_indices
# 1377  primary_sectors  global_indices

# %%
stock_index =investpy.indices.get_indices(country="united states")
stock_index[(stock_index['market']=='global_indices') & (stock_index['class']=='other_indices')]
# Out:
#             country                                               name  \
# 0     united states                                NQ US Mid Cap Value
# 1     united states                               NQ US Mid Cap Growth
# 2     united states         NQ US Mid Cap Telecommunications Equipment
# 3     united states                       NQ US Mid Cap Semiconductors
# 4     united states                    NQ US Mid Cap Computer Hardware
# ...             ...                                                ...
# 1219  united states                        NQ US Benchmark Industrials
# 1220  united states                        NQ US Benchmark Gold Mining
# 1221  united states                     NQ US Benchmark General Mining
# 1222  united states  NQ US Benchmark Electrical Components & Equipment
# 1224  united states                                  CRSP US Small Cap
#
#                                               full_name     symbol currency  \
# 0                               NASDAQ US Mid Cap Value     NQUSMV      USD
# 1                              NASDAQ US Mid Cap Growth     NQUSMG      USD
# 2        NASDAQ US Mid Cap Telecommunications Equipment  NQUSM9578      USD
# 3                      NASDAQ US Mid Cap Semiconductors  NQUSM9576      USD
# 4                   NASDAQ US Mid Cap Computer Hardware  NQUSM9572      USD
# ...                                                 ...        ...      ...
# 1219                    NASDAQ US Benchmark Industrials  NQUSB2000      USD
# 1220                    NASDAQ US Benchmark Gold Mining  NQUSB1777      USD
# 1221                 NASDAQ US Benchmark General Mining  NQUSB1775      USD
# 1222  NASDAQ US Benchmark Electrical Components & Eq...  NQUSB2733      USD
# 1224                                  CRSP US Small Cap    CRSPSC1      USD
#
#               class          market
# 0     other_indices  global_indices
# 1     other_indices  global_indices
# 2     other_indices  global_indices
# 3     other_indices  global_indices
# 4     other_indices  global_indices
# ...             ...             ...
# 1219  other_indices  global_indices
# 1220  other_indices  global_indices
# 1221  other_indices  global_indices
# 1222  other_indices  global_indices
# 1224  other_indices  global_indices
#
# [638 rows x 7 columns]

# %%
dow =stock_index[(stock_index['market']=='global_indices') & (stock_index['class']=='other_indices')]
dow[dow['name'].str.contains('DJ')]
# Out:
#             country                                 name  \
# 475   united states               DJ U.S. Select REIT TR
# 476   united states           DJ U.S. Select Dividend TR
# 477   united states       DJ U.S. Select Dividend Net TR
# 991   united states               DJ U.S. Relative Value
# 992   united states           DJ U.S. Thematic Long Size
# 993   united states        DJ U.S. Thematic Long Quality
# 994   united states                DJ U.S. High Momentum
# 995   united states                       DJ US Low Beta
# 996   united states        DJ U.S. Select Regional Banks
# 997   united states         DJ US Select Pharmaceuticals
# 998   united states  DJ US Select Oil Equipment Services
# 999   united states    DJ US Select Oil Exploration Prod
# 1000  united states       DJ US Select Medical Equipment
# 1001  united states     DJ US Select Investment Services
# 1002  united states       DJ US Select Home Construction
# 1003  united states   DJ US Select Health Care Providers
# 1004  united states       DJ US Select Aerospace Defense
# 1015  united states                            DJIAF 4XS
# 1016  united states  DJ US Thematic Market Neut Low Beta
# 1017  united states                            DJIAF 3XS
# 1018  united states  DJ US Thematic Market Neut Momentum
# 1019  united states   DJ US Thematic Market Neutral Size
# 1021  united states       DJ Islamic Market US Small-Cap
# 1022  united states       DJ Islamic Market US Large-Cap
# 1023  united states   DJ Global ex-US Select Real Estate
# 1024  united states             DJ US Select Real Estate
# 1025  united states                 DJ U.S. Target Today
# 1026  united states                  DJ U.S. Target 2055
# 1027  united states                  DJ U.S. Target 2050
# 1028  united states                  DJ U.S. Target 2045
# 1029  united states                  DJ U.S. Target 2040
# 1030  united states                  DJ U.S. Target 2035
# 1031  united states                  DJ U.S. Target 2030
# 1032  united states                  DJ U.S. Target 2025
# 1033  united states                  DJ U.S. Target 2020
# 1034  united states                  DJ U.S. Target 2015
# 1035  united states                  DJ U.S. Target 2010
# 1036  united states                  DJ U.S. Target 2005
# 1037  united states       DJ Islamic Market US Titans 50
# 1038  united states   DJ US Select Equal Weight REIT CAD
# 1039  united states   DJ US Select Equal Weight REIT USD
# 1040  united states         DJ U.S. Short Relative Value
# 1041  united states          DJ U.S. Thematic Short Size
# 1042  united states         DJ US Thematic Short Quality
# 1043  united states                 DJ U.S. Low Momentum
# 1044  united states                      DJ US High Beta
# 1045  united states   DJ US Thematic Market Neut Quality
# 1046  united states                            DJIAF 4XL
# 1047  united states                            DJIAF 3XL
# 1048  united states           DJ US Mid Cap Total Market
#
#                                               full_name    symbol currency  \
# 475             Dow Jones U.S. Select REIT Total Return    DWRTFT      USD
# 476         Dow Jones U.S. Select Dividend Total Return     DJDVY      USD
# 477     Dow Jones U.S. Select Dividend Net Total Return     DJDVN      USD
# 991                         Dow Jones US Relative Value    DJTLSV      USD
# 992                     Dow Jones US Thematic Long Size    DJTLSS      USD
# 993                  Dow Jones US Thematic Long Quality    DJTLQU      USD
# 994                          Dow Jones US High Momentum    DJTLMO      USD
# 995                               Dow Jones US Low Beta    DJTLAB      USD
# 996                  Dow Jones US Select Regional Banks    DJSRBK      USD
# 997                 Dow Jones US Select Pharmaceuticals    DJSPHM      USD
# 998        Dow Jones US Select Oil Equipment & Services    DJSOES      USD
# 999    Dow Jones US Select Oil Exploration & Production    DJSOEP      USD
# 1000              Dow Jones US Select Medical Equipment    DJSMDQ      USD
# 1001            Dow Jones US Select Investment Services    DJSINV      USD
# 1002              Dow Jones US Select Home Construction    DJSHMB      USD
# 1003          Dow Jones US Select Health Care Providers    DJSHCP      USD
# 1004            Dow Jones US Select Aerospace & Defense    DJSASD      USD
# 1015                       DJI Average Futures 4x Short      X0DK      USD
# 1016      Dow Jones US Thematic Market Neutral Low Beta   DJTMNAB      USD
# 1017                       DJI Average Futures 3x Short      X0DJ      USD
# 1018      Dow Jones US Thematic Market Neutral Momentum   DJTMNMO      USD
# 1019          Dow Jones US Thematic Market Neutral Size   DJTMNSS      USD
# 1021              Dow Jones Islamic Market US Small-Cap     IMUSS      USD
# 1022              Dow Jones Islamic Market US Large-Cap     IMUSL      USD
# 1023  Dow Jones Global ex-US Select Real Estate Secu...     DWXRS      USD
# 1024         Dow Jones US Select Real Estate Securities     DWRSF      USD
# 1025                          Dow Jones US Target Today   DJUSTGT      USD
# 1026                           Dow Jones US Target 2055  DJUSTG55      USD
# 1027                           Dow Jones US Target 2050  DJUSTG50      USD
# 1028                           Dow Jones US Target 2045  DJUSTG45      USD
# 1029                           Dow Jones US Target 2040  DJUSTG40      USD
# 1030                           Dow Jones US Target 2035  DJUSTG35      USD
# 1031                           Dow Jones US Target 2030  DJUSTG30      USD
# 1032                           Dow Jones US Target 2025  DJUSTG25      USD
# 1033                           Dow Jones US Target 2020  DJUSTG20      USD
# 1034                           Dow Jones US Target 2015  DJUSTG15      USD
# 1035                           Dow Jones US Target 2010  DJUSTG10      USD
# 1036                           Dow Jones US Target 2005  DJUSTG05      USD
# 1037              Dow Jones Islamic Market US Titans 50    DJUS50      USD
# 1038          Dow Jones US Select Equal Weight REIT CAD  DJURTEWC      CAD
# 1039          Dow Jones US Select Equal Weight REIT USD   DJURTEW      USD
# 1040                  Dow Jones US Short Relative Value    DJTSSV      USD
# 1041                   Dow Jones US Thematic Short Size    DJTSSS      USD
# 1042                Dow Jones US Thematic Short Quality    DJTSQU      USD
# 1043                          Dow Jones US Low Momentum    DJTSMO      USD
# 1044                             Dow Jones US High Beta    DJTSAB      USD
# 1045       Dow Jones US Thematic Market Neutral Quality   DJTMNQU      USD
# 1046                        DJI Average Futures 4x Long      X0DI      USD
# 1047                        DJI Average Futures 3x Long      X0DH      USD
# 1048                  Dow Jones US Mid-Cap Total Market       DWM      USD
#
#               class          market
# 475   other_indices  global_indices
# 476   other_indices  global_indices
# 477   other_indices  global_indices
# 991   other_indices  global_indices
# 992   other_indices  global_indices
# 993   other_indices  global_indices
# 994   other_indices  global_indices
# 995   other_indices  global_indices
# 996   other_indices  global_indices
# 997   other_indices  global_indices
# 998   other_indices  global_indices
# 999   other_indices  global_indices
# 1000  other_indices  global_indices
# 1001  other_indices  global_indices
# 1002  other_indices  global_indices
# 1003  other_indices  global_indices
# 1004  other_indices  global_indices
# 1015  other_indices  global_indices
# 1016  other_indices  global_indices
# 1017  other_indices  global_indices
# 1018  other_indices  global_indices
# 1019  other_indices  global_indices
# 1021  other_indices  global_indices
# 1022  other_indices  global_indices
# 1023  other_indices  global_indices
# 1024  other_indices  global_indices
# 1025  other_indices  global_indices
# 1026  other_indices  global_indices
# 1027  other_indices  global_indices
# 1028  other_indices  global_indices
# 1029  other_indices  global_indices
# 1030  other_indices  global_indices
# 1031  other_indices  global_indices
# 1032  other_indices  global_indices
# 1033  other_indices  global_indices
# 1034  other_indices  global_indices
# 1035  other_indices  global_indices
# 1036  other_indices  global_indices
# 1037  other_indices  global_indices
# 1038  other_indices  global_indices
# 1039  other_indices  global_indices
# 1040  other_indices  global_indices
# 1041  other_indices  global_indices
# 1042  other_indices  global_indices
# 1043  other_indices  global_indices
# 1044  other_indices  global_indices
# 1045  other_indices  global_indices
# 1046  other_indices  global_indices
# 1047  other_indices  global_indices
# 1048  other_indices  global_indices

# %%
stock_index =investpy.indices.get_indices(country="united states")
stock_index[stock_index['full_name'].str.contains('Dow Jones Industrial')]
# Out:
#            country                                name  \
# 393  united states                              Dow 30
# 402  united states                      DJ Industrials
# 543  united states             DJ Industrial Suppliers
# 554  united states        DJ Industrial & Office REITs
# 555  united states           DJ Industrial Engineering
# 556  united states      DJ Industrial Goods & Services
# 557  united states             DJ Industrial Machinery
# 558  united states       DJ Industrial Metals & Mining
# 559  united states        DJ Industrial Transportation
# 761  united states  1/100 Dow Jones Industrial Average
#
#                                  full_name  symbol currency            class  \
# 393           Dow Jones Industrial Average     DJI      USD    major_indices
# 402                  Dow Jones Industrials  DJUSIN      USD  primary_sectors
# 543         Dow Jones Industrial Suppliers  DJUSDS      USD    other_indices
# 554    Dow Jones Industrial & Office REITs  DJUSIO      USD    other_indices
# 555       Dow Jones Industrial Engineering  DJUSIQ      USD    other_indices
# 556  Dow Jones Industrial Goods & Services  DJUSIG      USD    other_indices
# 557         Dow Jones Industrial Machinery  DJUSFE      USD    other_indices
# 558   Dow Jones Industrial Metals & Mining  DJUSIM      USD    other_indices
# 559    Dow Jones Industrial Transportation  DJUSIT      USD    other_indices
# 761     1/100 Dow Jones Industrial Average     DJX      USD    other_indices
#
#             market
# 393  world_indices
# 402  world_indices
# 543  world_indices
# 554  world_indices
# 555  world_indices
# 556  world_indices
# 557  world_indices
# 558  world_indices
# 559  world_indices
# 761  world_indices

# %%
index_list = investpy.indices.get_index_countries()
index_list
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'ivory coast',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'luxembourg',
#  'malawi',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestinian territory',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
#  'russia',
#  'rwanda',
#  'saudi arabia',
#  'serbia',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'sweden',
#  'switzerland',
#  'taiwan',
#  'tanzania',
#  'thailand',
#  'tunisia',
#  'turkey',
#  'uganda',
#  'ukraine',
#  'dubai',
#  'united kingdom',
#  'united states',
#  'venezuela',
#  'vietnam',
#  'world',
#  'zambia',
#  'zimbabwe',
#  'euro zone']

# %%
euro_index =investpy.indices.get_indices(country="germany")
euro_index[euro_index['name'].str.contains('DAX')]
# Out:
#      country                     name                      full_name  \
# 10   germany          XETRA DAX Price                XETRA DAX Price
# 34   germany        Long DAX x3 AR TR    Long DAX x3 AR Total Return
# 37   germany             TecDAX Price                   TecDAX Price
# 42   germany           ShortDAX x2 TR       ShortDAX x2 Total Return
# 43   germany       Short DAX x3 AR TR   Short DAX x3 AR Total Return
# 44   germany               SDAX Price                     SDAX Price
# 59   germany                     HDAX                           HDAX
# 60   germany             LEVDAX X5 TR         LEVDAX X5 Total Return
# 81   germany                   TecDAX                         TecDAX
# 82   germany                     SDAX                           SDAX
# 84   germany         LevDAX x2 TR EUR     LevDAX x2 Total Return EUR
# 87   germany               HDAX Price                     HDAX Price
# 88   germany                HDAX Pref                      HDAX Pref
# 95   germany            DAXplus Price  DAXplus Export Strategy Price
# 96   germany                  DAXplus        DAXplus Export Strategy
# 98   germany                DAX Price                      DAX Price
# 99   germany                 VDAX New             DAX New Volatility
# 102  germany              DAX BRIC PR                    DAX BRIC PR
# 112  germany                DivDAX PF                      DivDAX PF
# 113  germany                DivDAX PR                      DivDAX PR
# 114  germany            DAX Kursindex                  DAX Kursindex
# 120  germany      LevDAX x2 Kursindex            LevDAX x2 Kursindex
# 131  germany  DAX x3 Levereged EUR TR        DAX x3 Levereged EUR TR
# 132  germany       ShortDAX x3 EUR TR             ShortDAX x3 EUR TR
# 133  germany                 DAXF 3XL            DAX Futures Long x3
# 141  germany                 X DAX PR                    X-DAX Price
# 142  germany         TECDAXF 4XS INDX        TecDAX Futures Short x4
# 143  germany         TECDAXF 3XS INDX        TecDAX Futures Short x3
# 144  germany         TECDAXF 4XL INDX         TecDAX Futures Long x4
# 145  germany         TECDAXF 3XL INDX         TecDAX Futures Long x3
# 146  germany                MDAXF 4XS    Midcap DAX Futures Short x4
# 147  germany                MDAXF 3XS    Midcap DAX Futures Short x3
# 148  germany                MDAXF 4XL     Midcap DAX Futures Long x4
# 149  germany                MDAXF 3XL     Midcap DAX Futures Long x3
# 150  germany                 DAXF 4XS           DAX Futures Short x4
# 151  germany                 DAXF 3XS           DAX Futures Short x3
# 152  germany                 DAXF 4XL            DAX Futures Long x4
# 167  germany                      DAX                            DAX
#
#         symbol currency               class          market
# 10         DAX      EUR  additional_indices   world_indices
# 34     LEVDAX3      EUR       other_indices   world_indices
# 37     TECDAXP      EUR       other_indices   world_indices
# 42   SHORTDAX2      EUR       other_indices   world_indices
# 43     SHRTDX3      EUR       other_indices   world_indices
# 44      SDAXIP      EUR       other_indices   world_indices
# 59      GDAXHI      EUR  additional_indices   world_indices
# 60     LEVDAX5      EUR       other_indices   world_indices
# 81      TECDAX      EUR  additional_indices   world_indices
# 82       SDAXI      EUR  additional_indices   world_indices
# 84      LEVDAX      EUR       other_indices   world_indices
# 87     GDAXHIP      EUR       other_indices   world_indices
# 88       GDAXH      EUR       other_indices   world_indices
# 95       DAXEP      EUR       other_indices   world_indices
# 96        DAXE      EUR       other_indices   world_indices
# 98      GDAXIP      EUR       other_indices   world_indices
# 99        V1XI      EUR       other_indices   world_indices
# 102   DAXBRICP      EUR       other_indices   world_indices
# 112       GSUL      EUR       other_indices  global_indices
# 113       GSUK      EUR       other_indices  global_indices
# 114      GDAXP      EUR       other_indices  global_indices
# 120  LEVDAX2PR      EUR       other_indices  global_indices
# 131    LEDAX3A      EUR       other_indices  global_indices
# 132    SHRDX3A      EUR       other_indices  global_indices
# 133       X00C      EUR       other_indices  global_indices
# 141       XDAX      EUR       other_indices  global_indices
# 142       X00Z      EUR       other_indices  global_indices
# 143       X00Y      EUR       other_indices  global_indices
# 144       X00U      EUR       other_indices  global_indices
# 145       X00T      EUR       other_indices  global_indices
# 146       X00Q      EUR       other_indices  global_indices
# 147       X00P      EUR       other_indices  global_indices
# 148       X00L      EUR       other_indices  global_indices
# 149       X00K      EUR       other_indices  global_indices
# 150       X00H      EUR       other_indices  global_indices
# 151       X00G      EUR       other_indices  global_indices
# 152       X00D      EUR       other_indices  global_indices
# 167      GDAXI      EUR       major_indices   world_indices

# %%
dax = investpy.get_index_historical_data(index='DAX',country='germany',
                                        from_date='01/01/2010',to_date=today)

# %%
dax.index = dax.index.strftime('%Y/%m/%d')
dax = dax.T
dax = dax.T.reset_index()

# %%
chart =(
    alt.Chart(dax)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)

# %%
euro_index =investpy.indices.get_indices(country="germany")
euro_index[euro_index['name'].str.contains('Euro Stoxx 50')]
# Out:
#      country           name      full_name    symbol currency          class  \
# 168  germany  Euro Stoxx 50  Euro Stoxx 50  STOXX50E      EUR  major_indices
#
#             market
# 168  world_indices

# %%
euro_stock50 = investpy.get_index_historical_data(index='Euro Stoxx 50',country='germany',
                                        from_date='01/01/2010',to_date=today)

# %%
euro_stock50.index = euro_stock50.index.strftime('%Y/%m/%d')
euro_stock50 = euro_stock50.T
euro_stock50 = euro_stock50.T.reset_index()

# %%
chart =(
    alt.Chart(euro_stock50)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)

# %%
uk_index =investpy.indices.get_indices(country="united kingdom")
f_index =investpy.indices.get_indices(country="france")

# %%
uk_index[uk_index['full_name'].str.contains('FTSE 100')]
# Out:
#             country                                             name  \
# 0    united kingdom                        FTSE 100 Minimum Variance
# 33   united kingdom  FTSE 100 Daily Ultra Short Strategy RT Gross TR
# 34   united kingdom             FTSE 100 Daily Super Leveraged RT TR
# 56   united kingdom                FTSE 100 Equally Weighted Net Tax
# 57   united kingdom                             FTSE 100 Daily Short
# 58   united kingdom                                     FTSE 100 USD
# 80   united kingdom                            FTSE 100 Total Return
# 136  united kingdom                                         FTSE 100
#
#                                            full_name    symbol currency  \
# 0                          FTSE 100 Minimum Variance   FTUKXMV      GBP
# 33   FTSE 100 Daily Ultra Short Strategy RT Gross TR  FTUKXI3X      GBP
# 34              FTSE 100 Daily Super Leveraged RT TR  FTUKXL3X      GBP
# 56                 FTSE 100 Equally Weighted Net Tax   FTUKXEQ      GBP
# 57                              FTSE 100 Daily Short    FTUKXS      GBP
# 58                                      FTSE 100 USD  FTUKXUSD      USD
# 80                             FTSE 100 Total Return    TRIUKX      GBP
# 136                                         FTSE 100      FTSE      GBP
#
#              class          market
# 0    other_indices  global_indices
# 33   other_indices  global_indices
# 34   other_indices  global_indices
# 56   other_indices  global_indices
# 57   other_indices  global_indices
# 58   other_indices  global_indices
# 80   other_indices   world_indices
# 136  major_indices   world_indices

# %%
ftse = investpy.get_index_historical_data(index='FTSE 100',country='united kingdom',
                                        from_date='01/01/2010',to_date=today)

# %%
ftse.index = ftse.index.strftime('%Y/%m%d')
ftse = ftse.T
ftse = ftse.T.reset_index()
ftse
# Out:
#            Date     Open     High      Low    Close     Volume Currency
# 0     2010/0104   5412.9   5500.3   5410.8   5500.3          0      GBP
# 1     2010/0105   5500.3   5536.4   5480.7   5522.5          0      GBP
# 2     2010/0106   5522.5   5536.5   5497.6   5530.0          0      GBP
# 3     2010/0107   5530.0   5551.7   5499.8   5526.7          0      GBP
# 4     2010/0108   5526.7   5549.3   5494.8   5534.2          0      GBP
# ...         ...      ...      ...      ...      ...        ...      ...
# 2964  2021/0927  7051.48  7122.09  7043.21   7063.4  900054016      GBP
# 2965  2021/0928   7063.4  7071.36  7015.58   7028.1  818880000      GBP
# 2966  2021/0929   7028.1  7117.52  7026.85  7108.16  810524992      GBP
# 2967  2021/0930  7108.16  7159.61  7072.57  7086.42  867449984      GBP
# 2968  2021/1001  7086.42  7086.42  6989.64  7027.07  815417024      GBP
#
# [2969 rows x 7 columns]

# %%
chart =(
    alt.Chart(ftse)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Close:Q",stack=None)
    )
)
chart
# Out:
# alt.Chart(...)
