# %%
# !pip install investpy
# Out:
# Requirement already satisfied: investpy in /home/snowpool/anaconda3/lib/python3.8/site-packages (1.0.6)
# Requirement already satisfied: Unidecode>=1.1.1 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (1.2.0)
# Requirement already satisfied: numpy>=1.17.2 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (1.20.2)
# Requirement already satisfied: setuptools>=41.2.0 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (52.0.0.post20210125)
# Requirement already satisfied: pandas>=0.25.1 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (1.2.2)
# Requirement already satisfied: requests>=2.22.0 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (2.22.0)
# Requirement already satisfied: pytz>=2019.3 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (2020.5)
# Requirement already satisfied: lxml>=4.4.1 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from investpy) (4.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->investpy) (2.8.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->investpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->investpy) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->investpy) (1.25.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->investpy) (2.8)
# Requirement already satisfied: six>=1.5 in /home/snowpool/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.15.0)

# %%
import pandas as pd
import investpy

# %%
code = '7203' #トヨタ自動車
stock_data = investpy.get_stock_historical_data(stock=code, country='japan', from_date='01/02/2021', to_date='28/03/2021')
stock_data.tail(5)
# Out:
#               Open    High     Low   Close  Volume Currency
# Date
# 2021-03-22  8542.5  8546.0  8373.5  8375.0       0      JPY
# 2021-03-23  8405.0  8468.0  8305.5  8311.5       0      JPY
# 2021-03-24  8235.5  8302.5  8114.0  8135.5       0      JPY
# 2021-03-25  8225.5  8244.5  8133.0  8162.5       0      JPY
# 2021-03-26  8267.0  8376.5  8239.0  8360.0       0      JPY

# %%
symbol = "AAPL" #アップル
stock_data = investpy.get_stock_historical_data(stock=symbol, country='united states', from_date='01/02/2021', to_date='28/03/2021')
stock_data.tail(5)
# Out:
#               Open    High     Low   Close     Volume Currency
# Date
# 2021-03-22  120.33  123.87  120.26  123.39  111912000      USD
# 2021-03-23  123.33  124.24  122.14  122.54   95467000      USD
# 2021-03-24  122.82  122.90  120.07  120.09   88530000      USD
# 2021-03-25  119.54  121.66  119.00  120.59   98845000      USD
# 2021-03-26  120.35  121.48  118.92  121.21   94071000      USD

# %%
usd_jpy = investpy.get_currency_cross_historical_data(currency_cross='USD/JPY', from_date='01/02/2021', to_date='28/03/2021')
usd_jpy.tail(5)
# Out:
#               Open    High     Low   Close Currency
# Date
# 2021-03-22  108.86  108.96  108.51  108.83      JPY
# 2021-03-23  108.85  108.89  108.40  108.56      JPY
# 2021-03-24  108.59  108.96  108.44  108.72      JPY
# 2021-03-25  108.74  109.24  108.71  109.17      JPY
# 2021-03-26  109.18  109.86  109.13  109.64      JPY

# %%
import datetime

# %%
economic_data = investpy.economic_calendar(time_zone=None, time_filter='time_only', countries=['japan', 'united states'], from_date='01/02/2021', to_date='28/03/2021')
economic_data.tail(5)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-1b70c5fb8006> in <module>
# ----> 1 economic_data = investpy.economic_calendar(time_zone=None, time_filter='time_only', countries=['japan', 'united states'], from_date='01/02/2021', to_date='28/03/2021')
#       2 economic_data.tail(5)
#
# ~/anaconda3/lib/python3.8/site-packages/investpy/news.py in economic_calendar(time_zone, time_filter, countries, importances, categories, from_date, to_date)
#     205         req = requests.post(url, headers=headers, data=data)
#     206
# --> 207         root = fromstring(req.json()['data'])
#     208         table = root.xpath(".//tr")
#     209
#
# ~/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
economic_data[economic_data['importance']=='high']
# Out:
#          id        date   time           zone currency importance  \
# 8    422215  02/02/2021  00:00  united states      USD       high
# 33   422323  03/02/2021  22:15  united states      USD       high
# 41   422333  04/02/2021  00:00  united states      USD       high
# 43   423350  04/02/2021  00:30  united states      USD       high
# 64   423364  04/02/2021  22:30  united states      USD       high
# ..      ...         ...    ...            ...      ...        ...
# 842  425376  24/03/2021  21:30  united states      USD       high
# 850  426345  24/03/2021  23:00  united states      USD       high
# 851  426322  24/03/2021  23:30  united states      USD       high
# 872  425462  25/03/2021  21:30  united states      USD       high
# 875  426359  25/03/2021  21:30  united states      USD       high
#
#                                       event   actual forecast previous
# 8              ISM Manufacturing PMI  (Jan)     58.7     60.0     60.5
# 33     ADP Nonfarm Employment Change  (Jan)     174K      49K     -78K
# 41         ISM Non-Manufacturing PMI  (Jan)     58.7     56.8     57.7
# 43                    Crude Oil Inventories  -0.994M   0.446M  -9.910M
# 64                   Initial Jobless Claims     779K     830K     812K
# ..                                      ...      ...      ...      ...
# 842  Core Durable Goods Orders (MoM)  (Feb)    -0.9%     0.6%     1.6%
# 850              Fed Chair Powell Testifies     None     None     None
# 851                   Crude Oil Inventories   1.912M  -0.272M   2.396M
# 872                         GDP (QoQ)  (Q4)     4.3%     4.1%    33.4%
# 875                  Initial Jobless Claims     684K     730K     781K
#
# [68 rows x 10 columns]

# %%
stock = '6501' # Hitachi Ltd
country = 'japan'

stock_df = investpy.get_stock_recent_data(stock=stock, country=country)
stock_df
# Out:
#               Open    High     Low   Close   Volume Currency
# Date
# 2021-06-04  5989.0  6080.0  5967.0  6063.0  3626300      JPY
# 2021-06-07  6063.0  6131.0  5998.0  6080.0  4955800      JPY
# 2021-06-08  6065.0  6098.0  6034.0  6088.0  3057900      JPY
# 2021-06-09  6058.0  6178.0  6054.0  6154.0  3831900      JPY
# 2021-06-10  6150.0  6170.0  6064.0  6073.0  3238900      JPY
# 2021-06-11  6014.0  6069.0  5966.0  5983.0  3911200      JPY
# 2021-06-14  6017.0  6052.0  5997.0  6032.0  1733900      JPY
# 2021-06-15  6012.0  6111.0  6002.0  6100.0  3240100      JPY
# 2021-06-16  6152.0  6270.0  6150.0  6251.0  3840200      JPY
# 2021-06-17  6185.0  6248.0  6178.0  6181.0  3495000      JPY
# 2021-06-18  6186.0  6202.0  6142.0  6142.0  3182100      JPY
# 2021-06-21  5988.0  6036.0  5877.0  5887.0  5116100      JPY
# 2021-06-22  6087.0  6270.0  6075.0  6258.0  4926700      JPY
# 2021-06-23  6229.0  6294.0  6188.0  6188.0  3344400      JPY
# 2021-06-24  6128.0  6178.0  6121.0  6158.0  1725500      JPY
# 2021-06-25  6228.0  6416.0  6220.0  6411.0  4724600      JPY
# 2021-06-28  6479.0  6525.0  6395.0  6489.0  4083500      JPY
# 2021-06-29  6430.0  6507.0  6419.0  6450.0  3395100      JPY
# 2021-06-30  6485.0  6489.0  6344.0  6361.0  4076800      JPY
# 2021-07-01  6425.0  6437.0  6314.0  6347.0  2151000      JPY
# 2021-07-02  6385.0  6483.0  6372.0  6480.0  2647900      JPY

# %%
stock = '6501' # Hitachi Ltd
country = 'japan'

stock_df = investpy.get_stock_recent_data(stock=stock, country=country)
stock_df.reset_index(drop=False, inplace=True)
stock_df.head()
# Out:
#         Date    Open    High     Low   Close   Volume Currency
# 0 2021-06-04  5989.0  6080.0  5967.0  6063.0  3626300      JPY
# 1 2021-06-07  6063.0  6131.0  5998.0  6080.0  4955800      JPY
# 2 2021-06-08  6065.0  6098.0  6034.0  6088.0  3057900      JPY
# 3 2021-06-09  6058.0  6178.0  6054.0  6154.0  3831900      JPY
# 4 2021-06-10  6150.0  6170.0  6064.0  6073.0  3238900      JPY

# %%
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns; sns.set()


fig,ax = plt.subplots(figsize=(12,4))
locator = mdates.DayLocator()
formatter = mdates.ConciseDateFormatter(locator)
ax.xaxis.set_minor_locator(locator)
ax.xaxis.set_major_formatter(formatter)

sns.lineplot(data=stock_df, x='Date', y='Close')
ax.set_title('Hitachi Ltdt')
plt.show()

# %%
economic_data = investpy.economic_calendar(time_zone=None, time_filter='time_only', countries=['japan', 'united states'], from_date='01/01/2021', to_date='11/06/2021')
economic_data[economic_data['event']=='Crude Oil Inventories']
# Out:
#           id        date   time           zone currency importance  \
# 71    421463  07/01/2021  00:30  united states      USD       high
# 188   421985  14/01/2021  00:30  united states      USD       high
# 332   422541  23/01/2021  01:00  united states      USD       high
# 397   422897  28/01/2021  00:30  united states      USD       high
# 544   423350  04/02/2021  00:30  united states      USD       high
# 664   423650  11/02/2021  00:30  united states      USD       high
# 794   424306  19/02/2021  01:00  united states      USD       high
# 882   424679  25/02/2021  00:30  united states      USD       high
# 1026  425121  04/03/2021  00:30  united states      USD       high
# 1151  425483  11/03/2021  00:30  united states      USD       high
# 1264  425817  17/03/2021  23:30  united states      USD       high
# 1373  426322  24/03/2021  23:30  united states      USD       high
# 1496  426780  31/03/2021  23:30  united states      USD       high
# 1627  427098  07/04/2021  23:30  united states      USD       high
# 1736  427516  14/04/2021  23:30  united states      USD       high
# 1833  427916  21/04/2021  23:30  united states      USD       high
# 1941  428360  28/04/2021  23:30  united states      USD       high
# 2075  428787  05/05/2021  23:30  united states      USD       high
# 2194  429171  12/05/2021  23:30  united states      USD       high
# 2323  429669  19/05/2021  23:30  united states      USD       high
# 2421  430084  26/05/2021  23:30  united states      USD       high
# 2574  430605  04/06/2021  00:00  united states      USD       high
# 2662  430931  09/06/2021  23:30  united states      USD       high
#
#                       event   actual forecast previous
# 71    Crude Oil Inventories  -8.010M  -2.133M  -6.065M
# 188   Crude Oil Inventories  -3.247M  -2.266M  -8.010M
# 332   Crude Oil Inventories   4.351M  -1.167M  -3.247M
# 397   Crude Oil Inventories  -9.910M   0.430M   4.351M
# 544   Crude Oil Inventories  -0.994M   0.446M  -9.910M
# 664   Crude Oil Inventories  -6.644M   0.985M  -0.994M
# 794   Crude Oil Inventories  -7.258M  -2.429M  -6.644M
# 882   Crude Oil Inventories   1.285M  -5.190M  -7.258M
# 1026  Crude Oil Inventories  21.563M  -0.928M   1.285M
# 1151  Crude Oil Inventories  13.798M   0.816M  21.563M
# 1264  Crude Oil Inventories   2.396M   2.964M  13.798M
# 1373  Crude Oil Inventories   1.912M  -0.272M   2.396M
# 1496  Crude Oil Inventories  -0.876M   0.107M   1.912M
# 1627  Crude Oil Inventories  -3.522M  -1.436M  -0.876M
# 1736  Crude Oil Inventories  -5.889M  -2.889M  -3.522M
# 1833  Crude Oil Inventories   0.594M  -2.975M  -5.889M
# 1941  Crude Oil Inventories   0.090M   0.659M   0.594M
# 2075  Crude Oil Inventories  -7.990M  -2.346M   0.090M
# 2194  Crude Oil Inventories  -0.427M  -2.817M  -7.990M
# 2323  Crude Oil Inventories   1.321M   1.623M  -0.427M
# 2421  Crude Oil Inventories  -1.662M  -1.050M  -0.426M
# 2574  Crude Oil Inventories  -5.080M  -2.443M  -1.662M
# 2662  Crude Oil Inventories  -5.241M  -2.036M  -5.080M

# %%
economic_data[economic_data['event']=='Initial Jobless Claims']
# Out:
#           id        date   time           zone currency importance  \
# 92    421535  07/01/2021  22:30  united states      USD       high
# 220   422023  14/01/2021  22:30  united states      USD       high
# 309   422523  21/01/2021  22:30  united states      USD       high
# 426   422919  28/01/2021  22:30  united states      USD       high
# 565   423364  04/02/2021  22:30  united states      USD       high
# 682   423681  11/02/2021  22:30  united states      USD       high
# 785   424302  18/02/2021  22:30  united states      USD       high
# 910   424717  25/02/2021  22:30  united states      USD       high
# 1057  425153  04/03/2021  22:30  united states      USD       high
# 1171  425541  11/03/2021  22:30  united states      USD       high
# 1285  425855  18/03/2021  21:30  united states      USD       high
# 1397  426359  25/03/2021  21:30  united states      USD       high
# 1537  426838  01/04/2021  21:30  united states      USD       high
# 1648  427144  08/04/2021  21:30  united states      USD       high
# 1758  427563  15/04/2021  21:30  united states      USD       high
# 1848  427995  22/04/2021  21:30  united states      USD       high
# 1962  428386  29/04/2021  21:30  united states      USD       high
# 2106  428813  06/05/2021  21:30  united states      USD       high
# 2221  429230  13/05/2021  21:30  united states      USD       high
# 2346  429712  20/05/2021  21:30  united states      USD       high
# 2445  430151  27/05/2021  21:30  united states      USD       high
# 2560  430601  03/06/2021  21:30  united states      USD       high
# 2688  430965  10/06/2021  21:30  united states      USD       high
#
#                        event actual forecast previous
# 92    Initial Jobless Claims   787K     800K     790K
# 220   Initial Jobless Claims   965K     795K     784K
# 309   Initial Jobless Claims   900K     910K     926K
# 426   Initial Jobless Claims   847K     875K     914K
# 565   Initial Jobless Claims   779K     830K     812K
# 682   Initial Jobless Claims   793K     757K     812K
# 785   Initial Jobless Claims   861K     765K     848K
# 910   Initial Jobless Claims   730K     838K     841K
# 1057  Initial Jobless Claims   745K     750K     736K
# 1171  Initial Jobless Claims   712K     725K     754K
# 1285  Initial Jobless Claims   770K     700K     725K
# 1397  Initial Jobless Claims   684K     730K     781K
# 1537  Initial Jobless Claims   719K     680K     658K
# 1648  Initial Jobless Claims   744K     680K     728K
# 1758  Initial Jobless Claims   576K     700K     769K
# 1848  Initial Jobless Claims   547K     617K     586K
# 1962  Initial Jobless Claims   553K     549K     566K
# 2106  Initial Jobless Claims   498K     540K     590K
# 2221  Initial Jobless Claims   473K     490K     507K
# 2346  Initial Jobless Claims   444K     450K     478K
# 2445  Initial Jobless Claims   406K     425K     444K
# 2560  Initial Jobless Claims   385K     390K     405K
# 2688  Initial Jobless Claims   376K     370K     405K

# %%
economic_data[economic_data['event'].str.contains('ISM Non-Manufacturing PMI')]
# Out:
#           id        date   time           zone currency importance  \
# 99    420814  08/01/2021  00:00  united states      USD       high
# 542   422333  04/02/2021  00:00  united states      USD       high
# 1024  424139  04/03/2021  00:00  united states      USD       high
# 1596  426093  05/04/2021  23:00  united states      USD       high
# 2073  427847  05/05/2021  23:00  united states      USD       high
# 2571  429650  03/06/2021  23:00  united states      USD       high
#
#                                  event actual forecast previous
# 99    ISM Non-Manufacturing PMI  (Dec)   57.2     54.6     55.9
# 542   ISM Non-Manufacturing PMI  (Jan)   58.7     56.8     57.7
# 1024  ISM Non-Manufacturing PMI  (Feb)   55.3     58.7     58.7
# 1596  ISM Non-Manufacturing PMI  (Mar)   63.7     59.0     55.3
# 2073  ISM Non-Manufacturing PMI  (Apr)   62.7     64.3     63.7
# 2571  ISM Non-Manufacturing PMI  (May)   64.0     63.0     62.7

# %%
economic_data2 = investpy.economic_calendar(time_zone=None, time_filter='time_only', countries=['japan', 'united states'], from_date='01/01/2021', to_date='31/01/2021')
economic_data2[economic_data2['importance']=='high']
# Out:
#          id        date       time           zone currency importance  \
# 48   420684  06/01/2021      00:00  united states      USD       high
# 62   421462  06/01/2021      22:15  united states      USD       high
# 71   421463  07/01/2021      00:30  united states      USD       high
# 81   421464  07/01/2021      04:00  united states      USD       high
# 92   421535  07/01/2021      22:30  united states      USD       high
# 99   420814  08/01/2021      00:00  united states      USD       high
# 118  420891  08/01/2021      22:30  united states      USD       high
# 122  420898  08/01/2021      22:30  united states      USD       high
# 156  411619  12/01/2021      21:00  united states      USD       high
# 162  421006  13/01/2021      00:00  united states      USD       high
# 178  421056  13/01/2021      22:30  united states      USD       high
# 188  421985  14/01/2021      00:30  united states      USD       high
# 220  422023  14/01/2021      22:30  united states      USD       high
# 226  422082  15/01/2021      02:30  united states      USD       high
# 230  422422  15/01/2021      09:15  united states      USD       high
# 235  421197  15/01/2021      22:30  united states      USD       high
# 238  421199  15/01/2021      22:30  united states      USD       high
# 240  421200  15/01/2021      22:30  united states      USD       high
# 291  422607  21/01/2021  Tentative  united states      USD       high
# 301  422374  21/01/2021      12:00          japan      JPY       high
# 302  422373  21/01/2021      12:00          japan      JPY       high
# 303  422376  21/01/2021      12:00          japan      JPY       high
# 304  421474  21/01/2021      22:30  united states      USD       high
# 309  422523  21/01/2021      22:30  united states      USD       high
# 311  421436  21/01/2021      22:30  united states      USD       high
# 329  421607  23/01/2021      00:00  united states      USD       high
# 332  422541  23/01/2021      01:00  united states      USD       high
# 375  421745  27/01/2021      00:00  united states      USD       high
# 393  421780  27/01/2021      22:30  united states      USD       high
# 397  422897  28/01/2021      00:30  united states      USD       high
# 407  422807  28/01/2021      04:00  united states      USD       high
# 408  411575  28/01/2021      04:00  united states      USD       high
# 409  422806  28/01/2021      04:30  united states      USD       high
# 416  421856  28/01/2021      22:30  united states      USD       high
# 420  422919  28/01/2021      22:30  united states      USD       high
# 427  421871  29/01/2021      00:00  united states      USD       high
# 475  422090  30/01/2021      00:00  united states      USD       high
#
#                                            event   actual forecast previous
# 48                  ISM Manufacturing PMI  (Dec)     60.7     56.6     57.5
# 62          ADP Nonfarm Employment Change  (Dec)    -123K      88K     304K
# 71                         Crude Oil Inventories  -8.010M  -2.133M  -6.065M
# 81                          FOMC Meeting Minutes     None     None     None
# 92                        Initial Jobless Claims     787K     800K     790K
# 99              ISM Non-Manufacturing PMI  (Dec)     57.2     54.6     55.9
# 118                      Nonfarm Payrolls  (Dec)    -140K      71K     336K
# 122                     Unemployment Rate  (Dec)     6.7%     6.8%     6.7%
# 156                EIA Short-Term Energy Outlook     None     None     None
# 162                    JOLTs Job Openings  (Nov)   6.527M     None   6.632M
# 178                        Core CPI (MoM)  (Dec)     0.1%     0.1%     0.2%
# 188                        Crude Oil Inventories  -3.247M  -2.266M  -8.010M
# 220                       Initial Jobless Claims     965K     795K     784K
# 226                      Fed Chair Powell Speaks     None     None     None
# 230                  U.S. President Biden Speaks     None     None     None
# 235               Core Retail Sales (MoM)  (Dec)    -1.4%    -0.1%    -1.3%
# 238                             PPI (MoM)  (Dec)     0.3%     0.4%     0.1%
# 240                    Retail Sales (MoM)  (Dec)    -0.7%    -0.2%    -1.4%
# 291                  U.S. President Biden Speaks     None     None     None
# 301                BoJ Monetary Policy Statement     None     None     None
# 302                     BoJ Outlook Report (YoY)     None     None     None
# 303                         BoJ Press Conference     None     None     None
# 304                      Building Permits  (Dec)   1.709M   1.604M   1.635M
# 309                       Initial Jobless Claims     900K     910K     926K
# 311  Philadelphia Fed Manufacturing Index  (Jan)     26.5     12.0      9.1
# 329                   Existing Home Sales  (Dec)    6.76M    6.55M    6.71M
# 332                        Crude Oil Inventories   4.351M  -1.167M  -3.247M
# 375                CB Consumer Confidence  (Jan)     89.3     89.0     87.1
# 393       Core Durable Goods Orders (MoM)  (Dec)     0.7%     0.5%     0.8%
# 397                        Crude Oil Inventories  -9.910M   0.430M   4.351M
# 407                               FOMC Statement     None     None     None
# 408                   Fed Interest Rate Decision    0.25%    0.25%    0.25%
# 409                        FOMC Press Conference     None     None     None
# 416                              GDP (QoQ)  (Q4)     4.0%     4.0%    33.4%
# 420                       Initial Jobless Claims     847K     875K     914K
# 427                        New Home Sales  (Dec)     842K     865K     829K
# 475              Pending Home Sales (MoM)  (Dec)    -0.3%    -0.1%    -2.5%

# %%
economic_data2[~(economic_data2['actual'].isnull()) & (economic_data2['importance']=='high')]
# Out:
#          id        date   time           zone currency importance  \
# 48   420684  06/01/2021  00:00  united states      USD       high
# 62   421462  06/01/2021  22:15  united states      USD       high
# 71   421463  07/01/2021  00:30  united states      USD       high
# 92   421535  07/01/2021  22:30  united states      USD       high
# 99   420814  08/01/2021  00:00  united states      USD       high
# 118  420891  08/01/2021  22:30  united states      USD       high
# 122  420898  08/01/2021  22:30  united states      USD       high
# 162  421006  13/01/2021  00:00  united states      USD       high
# 178  421056  13/01/2021  22:30  united states      USD       high
# 188  421985  14/01/2021  00:30  united states      USD       high
# 220  422023  14/01/2021  22:30  united states      USD       high
# 235  421197  15/01/2021  22:30  united states      USD       high
# 238  421199  15/01/2021  22:30  united states      USD       high
# 240  421200  15/01/2021  22:30  united states      USD       high
# 304  421474  21/01/2021  22:30  united states      USD       high
# 309  422523  21/01/2021  22:30  united states      USD       high
# 311  421436  21/01/2021  22:30  united states      USD       high
# 329  421607  23/01/2021  00:00  united states      USD       high
# 332  422541  23/01/2021  01:00  united states      USD       high
# 375  421745  27/01/2021  00:00  united states      USD       high
# 393  421780  27/01/2021  22:30  united states      USD       high
# 397  422897  28/01/2021  00:30  united states      USD       high
# 408  411575  28/01/2021  04:00  united states      USD       high
# 416  421856  28/01/2021  22:30  united states      USD       high
# 420  422919  28/01/2021  22:30  united states      USD       high
# 427  421871  29/01/2021  00:00  united states      USD       high
# 475  422090  30/01/2021  00:00  united states      USD       high
#
#                                            event   actual forecast previous
# 48                  ISM Manufacturing PMI  (Dec)     60.7     56.6     57.5
# 62          ADP Nonfarm Employment Change  (Dec)    -123K      88K     304K
# 71                         Crude Oil Inventories  -8.010M  -2.133M  -6.065M
# 92                        Initial Jobless Claims     787K     800K     790K
# 99              ISM Non-Manufacturing PMI  (Dec)     57.2     54.6     55.9
# 118                      Nonfarm Payrolls  (Dec)    -140K      71K     336K
# 122                     Unemployment Rate  (Dec)     6.7%     6.8%     6.7%
# 162                    JOLTs Job Openings  (Nov)   6.527M     None   6.632M
# 178                        Core CPI (MoM)  (Dec)     0.1%     0.1%     0.2%
# 188                        Crude Oil Inventories  -3.247M  -2.266M  -8.010M
# 220                       Initial Jobless Claims     965K     795K     784K
# 235               Core Retail Sales (MoM)  (Dec)    -1.4%    -0.1%    -1.3%
# 238                             PPI (MoM)  (Dec)     0.3%     0.4%     0.1%
# 240                    Retail Sales (MoM)  (Dec)    -0.7%    -0.2%    -1.4%
# 304                      Building Permits  (Dec)   1.709M   1.604M   1.635M
# 309                       Initial Jobless Claims     900K     910K     926K
# 311  Philadelphia Fed Manufacturing Index  (Jan)     26.5     12.0      9.1
# 329                   Existing Home Sales  (Dec)    6.76M    6.55M    6.71M
# 332                        Crude Oil Inventories   4.351M  -1.167M  -3.247M
# 375                CB Consumer Confidence  (Jan)     89.3     89.0     87.1
# 393       Core Durable Goods Orders (MoM)  (Dec)     0.7%     0.5%     0.8%
# 397                        Crude Oil Inventories  -9.910M   0.430M   4.351M
# 408                   Fed Interest Rate Decision    0.25%    0.25%    0.25%
# 416                              GDP (QoQ)  (Q4)     4.0%     4.0%    33.4%
# 420                       Initial Jobless Claims     847K     875K     914K
# 427                        New Home Sales  (Dec)     842K     865K     829K
# 475              Pending Home Sales (MoM)  (Dec)    -0.3%    -0.1%    -2.5%

# %%
import altair as alt

# %%
ISM =economic_data[economic_data['event'].str.contains('ISM Non-Manufacturing PMI')]
ISM
# Out:
#           id        date   time           zone currency importance  \
# 99    420814  08/01/2021  00:00  united states      USD       high
# 542   422333  04/02/2021  00:00  united states      USD       high
# 1024  424139  04/03/2021  00:00  united states      USD       high
# 1596  426093  05/04/2021  23:00  united states      USD       high
# 2073  427847  05/05/2021  23:00  united states      USD       high
# 2571  429650  03/06/2021  23:00  united states      USD       high
#
#                                  event actual forecast previous
# 99    ISM Non-Manufacturing PMI  (Dec)   57.2     54.6     55.9
# 542   ISM Non-Manufacturing PMI  (Jan)   58.7     56.8     57.7
# 1024  ISM Non-Manufacturing PMI  (Feb)   55.3     58.7     58.7
# 1596  ISM Non-Manufacturing PMI  (Mar)   63.7     59.0     55.3
# 2073  ISM Non-Manufacturing PMI  (Apr)   62.7     64.3     63.7
# 2571  ISM Non-Manufacturing PMI  (May)   64.0     63.0     62.7

# %%
ISM.columns
# Out:
# Index(['id', 'date', 'time', 'zone', 'currency', 'importance', 'event',
#        'actual', 'forecast', 'previous'],
#       dtype='object')

# %%
ISM.reset_index()
# Out:
#    index      id        date   time           zone currency importance  \
# 0     99  420814  08/01/2021  00:00  united states      USD       high
# 1    542  422333  04/02/2021  00:00  united states      USD       high
# 2   1024  424139  04/03/2021  00:00  united states      USD       high
# 3   1596  426093  05/04/2021  23:00  united states      USD       high
# 4   2073  427847  05/05/2021  23:00  united states      USD       high
# 5   2571  429650  03/06/2021  23:00  united states      USD       high
#
#                               event actual forecast previous
# 0  ISM Non-Manufacturing PMI  (Dec)   57.2     54.6     55.9
# 1  ISM Non-Manufacturing PMI  (Jan)   58.7     56.8     57.7
# 2  ISM Non-Manufacturing PMI  (Feb)   55.3     58.7     58.7
# 3  ISM Non-Manufacturing PMI  (Mar)   63.7     59.0     55.3
# 4  ISM Non-Manufacturing PMI  (Apr)   62.7     64.3     63.7
# 5  ISM Non-Manufacturing PMI  (May)   64.0     63.0     62.7

# %%
ISM.head()
# Out:
#           id        date   time           zone currency importance  \
# 99    420814  08/01/2021  00:00  united states      USD       high
# 542   422333  04/02/2021  00:00  united states      USD       high
# 1024  424139  04/03/2021  00:00  united states      USD       high
# 1596  426093  05/04/2021  23:00  united states      USD       high
# 2073  427847  05/05/2021  23:00  united states      USD       high
#
#                                  event actual forecast previous
# 99    ISM Non-Manufacturing PMI  (Dec)   57.2     54.6     55.9
# 542   ISM Non-Manufacturing PMI  (Jan)   58.7     56.8     57.7
# 1024  ISM Non-Manufacturing PMI  (Feb)   55.3     58.7     58.7
# 1596  ISM Non-Manufacturing PMI  (Mar)   63.7     59.0     55.3
# 2073  ISM Non-Manufacturing PMI  (Apr)   62.7     64.3     63.7

# %%
ISM.columns
# Out:
# Index(['id', 'date', 'time', 'zone', 'currency', 'importance', 'event',
#        'actual', 'forecast', 'previous'],
#       dtype='object')

# %%
import datetime

# %%
ism_act = ISM.filter(items=['date','actual'])
ism_act.dtypes
# Out:
# date      object
# actual    object
# dtype: object

# %%
ism_act['date']=pd.to_datetime(ism_act['date'], format='%Y%m%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     455             try:
# --> 456                 values, tz = conversion.datetime_to_datetime64(arg)
#     457                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-b3eeb1074c95> in <module>
# ----> 1 ism_act['date']=pd.to_datetime(ism_act['date'], format='%Y%m%d')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     803             result = arg.map(cache_array)
#     804         else:
# --> 805             values = convert_listlike(arg._values, format)
#     806             result = arg._constructor(values, index=arg.index, name=arg.name)
#     807     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     458                 return DatetimeIndex._simple_new(dta, name=name)
#     459             except (ValueError, TypeError):
# --> 460                 raise e
#     461
#     462     if result is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     421             if result is None:
#     422                 try:
# --> 423                     result, timezones = array_strptime(
#     424                         arg, format, exact=exact, errors=errors
#     425                     )
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '08/01/2021' does not match format '%Y%m%d' (match)

# %%
ism_act.sort_values(by='date')
# Out:
#             date actual
# 2571  03/06/2021   64.0
# 542   04/02/2021   58.7
# 1024  04/03/2021   55.3
# 1596  05/04/2021   63.7
# 2073  05/05/2021   62.7
# 99    08/01/2021   57.2

# %%
type(df_ism_act['date'][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-5d833b707dd1> in <module>
# ----> 1 type(df_ism_act['date'][0])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     849
#     850         elif key_is_scalar:
# --> 851             return self._get_value(key)
#     852
#     853         if is_hashable(key):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     957
#     958         # Similar to Index.get_value, but we do not fall back to positional
# --> 959         loc = self.index.get_loc(label)
#     960         return self.index._get_values_for_loc(self, loc, label)
#     961
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %%
ism_act['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df_ism_act.index.dayname()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-6c19f4de8769> in <module>
# ----> 1 df_ism_act.index.dayname()
#
# AttributeError: 'Int64Index' object has no attribute 'dayname'

# %%
chart =(
    alt.Chart(ism_act)
    .mark_line(opacity=0.8,clip=True)
    .encode(
        x="date:T",
        y=alt.Y("actual:Q",stack=None)
    )
)

# %%
chart
# Out:
# alt.Chart(...)
